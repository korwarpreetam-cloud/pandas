# %% [markdown]
# ### pandas

# %%
# !pip install pandas

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ---
# ### creating series and panda series

# %%
labels = ['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,index=arr)
# Out:
# 10    10
# 20    20
# 30    30
# dtype: int64

# %% [markdown]
# ---
# ### dataframes

# %% [markdown]
# ### creating dataframes

# %%
data = {
    'Name':['jhon', 'anna','peter','linda'],
    'age':[24,56,34,23],
    'city':['new york','mumbai','blr','deli'],
    'salary':[65000,88000,99000,78000]

}
df= pd.DataFrame(data)
# Out:
#     Name  age      city  salary
# 0   jhon   24  new york   65000
# 1   anna   56    mumbai   88000
# 2  peter   34       blr   99000
# 3  linda   23      deli   78000

# %%
df
# Out:
#     name  age         city  salary
# 0   john   23     new york    2000
# 1  jolli   24  los angeles    2500
# 2  peter   25      chicago    3000

# %%
data_list =[
    ['john',28,'new york',89000],
    ['ravi',89,'newziland',90000],
    ['gopal',45,'mumbai',70000],
    ['hari',13,'kerla',50000]
]
df2 = pd.DataFrame(data_list)
df2
columns = ["name","age","city","salary"]
df2=pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     name  age       city  salary
# 0   john   28   new york   89000
# 1   ravi   89  newziland   90000
# 2  gopal   45     mumbai   70000
# 3   hari   13      kerla   50000

# %% [markdown]
# ---
# ### selection and indexing of columns

# %%
df2
# Out:
#     name  age       city  salary
# 0   john   28   new york   89000
# 1   ravi   89  newziland   90000
# 2  gopal   45     mumbai   70000
# 3   hari   13      kerla   50000

# %%
df2['name']
# Out:
# 0     john
# 1     ravi
# 2    gopal
# 3     hari
# Name: name, dtype: str

# %%
df2['city']
# Out:
# 0     new york
# 1    newziland
# 2       mumbai
# 3        kerla
# Name: city, dtype: str

# %%
df2[['name','city']]
# Out:
#     name       city
# 0   john   new york
# 1   ravi  newziland
# 2  gopal     mumbai
# 3   hari      kerla

# %% [markdown]
# ---
# ### creating new column

# %%
df2["Designation"]=["doctor","eng","eng","eng"]
df2
# Out:
#     name  age       city  salary Designation
# 0   john   28   new york   89000      doctor
# 1   ravi   89  newziland   90000         eng
# 2  gopal   45     mumbai   70000         eng
# 3   hari   13      kerla   50000         eng

# %% [markdown]
# ---
# ### removing columns

# %%
df2
# Out:
#     name  age       city  salary Designation
# 0   john   28   new york   89000      doctor
# 1   ravi   89  newziland   90000         eng
# 2  gopal   45     mumbai   70000         eng
# 3   hari   13      kerla   50000         eng

# %%
df2.drop('Designation',axis=1)
# Out:
#     name  age       city  salary
# 0   john   28   new york   89000
# 1   ravi   89  newziland   90000
# 2  gopal   45     mumbai   70000
# 3   hari   13      kerla   50000

# %%
df2.drop('city',axis=1, inplace=True)

# %%
df2
# Out:
#     name  age  salary
# 0   john   28   89000
# 1   ravi   89   90000
# 2  gopal   45   70000
# 3   hari   13   50000

# %% [markdown]
# ---
# ### selecting rows

# %%
df2
# Out:
#     name  age  salary
# 0   john   28   89000
# 1   ravi   89   90000
# 2  gopal   45   70000
# 3   hari   13   50000

# %%
df2.loc[0]
# Out:
# name       john
# age          28
# salary    89000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#    name  age  salary
# 0  john   28   89000
# 1  ravi   89   90000

# %% [markdown]
# ---
# ### selecting subsets and rows and column

# %%
df2.loc[[0,1]][["name","salary"]]
# Out:
#    name  salary
# 0  john   89000
# 1  ravi   90000

# %% [markdown]
# ---
# ### conditional selection

# %%
df2
# Out:
#     name  age  salary
# 0   john   28   89000
# 1   ravi   89   90000
# 2  gopal   45   70000
# 3   hari   13   50000

# %%
# i only want to see who age is above 20

# %%
df2[df2["age"]>30]
# Out:
#     name  age  salary
# 1   ravi   89   90000
# 2  gopal   45   70000

# %%
#age above 30 and city must be paris
df2[(df2["age"]>30) & (df2["salary"]==90000)]
# Out:
#    name  age  salary
# 1  ravi   89   90000
