# %% [markdown]
# ### pandas

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=2.3.3 (from pandas)
#   Using cached numpy-2.4.3-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/preetam/Desktop/pylibry/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/preetam/Desktop/pylibry/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp314-cp314-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 8.0 MB/s  0:00:01m0:00:0100:01m
# Using cached numpy-2.4.3-cp314-cp314-macosx_14_0_arm64.whl (5.2 MB)
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.3 pandas-3.0.1
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np 
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ---
# ### creating series and panda series

# %%
labels = ['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,index=arr)
# Out:
# 10    10
# 20    20
# 30    30
# dtype: int64

# %% [markdown]
# ---
# ### dataframes

# %%
data ={
    'name':['john','jolli','peter'],
    'age':[23,24,25],
    'city':['new york','los angeles','chicago'],
    'salary':[2000,2500,3000]
    
}
df = pd.DataFrame(data)
# Out:
#     name  age         city  salary
# 0   john   23     new york    2000
# 1  jolli   24  los angeles    2500
# 2  peter   25      chicago    3000

# %%
data_list=[
    ['john',32,'male'],
    ['jane',28,'female'],
    ['mark',45,'male']
]
df2=pd.DataFrame(data_list)
columns=['name','age','gender']
df2=pd.DataFrame(data_list,columns=columns)
print(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       1 data_list=[
#       2     ['john',32,'male'],
#       3     ['jane',28,'female'],
#       4     ['mark',45,'male']
#       5 ]
# ----> 6 df2=pd.DataFrame(data_list)
#       7 columns=['name','age','gender']
#       8 df2=pd.DataFrame(data_list,columns=columns)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ---
# ### selection and indexing of col

# %%
df2
# Out:
#    name  age  gender
# 0  john   32    male
# 1  jane   28  female
# 2  mark   45    male

# %%
df2['name']
df2[['name','age']]
# Out:
#    name  age
# 0  john   32
# 1  jane   28
# 2  mark   45

# %% [markdown]
# ---
# ### creating new col

# %%
df2["designation"]=["doctor","nurse","nurse"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df2["designation"]=["doctor","nurse","nurse"]
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ---
# ### remove col

# %%
df2.drop('designation', axis=1, inplace=True)

df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df2.drop('Designation', axis=1)
#
# File ~/Desktop/pylibry/.venv/lib/python3.14/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File ~/Desktop/pylibry/.venv/lib/python3.14/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File ~/Desktop/pylibry/.venv/lib/python3.14/site-packages/pandas/core/generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File ~/Desktop/pylibry/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['Designation'] not found in axis"

# %%
print("abs")
# Out:
# abs
